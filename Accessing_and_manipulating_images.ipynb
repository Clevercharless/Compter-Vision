# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image as PilImage
from IPython.display import Image as IPyImage

# %matplotlib inline

# %%
cb_img = cv2.imread("/content/images.png", 0)

if cb_img is None:
    print("⚠️ Image not found. Double-check the file name/path.")
else:
    # Display with matplotlib
    plt.imshow(cb_img, cmap="gray")
    plt.axis("off")
    plt.show()

    print("Image shape:", cb_img.shape)
    print(cb_img)
# Out:
# Image shape: (225, 225)
# [[  0   0   0 ... 133 133 133]
#  [  0   0   0 ... 255 255 255]
#  [  0   0   0 ... 255 255 255]
#  ...
#  [133 255 255 ...   0   0   0]
#  [133 255 255 ...   0   0   0]
#  [133 255 255 ...   0   0   0]]

# %%
print(cb_img[224,0])
print(cb_img[165,4])
print(cb_img[2,5])
# Out:
# 133
# 255
# 0

# %%
cb_img_copy = cb_img.copy()

cb_img_copy[6,6]=200
cb_img_copy[6,44]=200
cb_img_copy[44,6]=200
cb_img_copy[44,44]=200

cb_img_copy[6:44, 6:44] = 200
plt.imshow(cb_img_copy, cmap="gray")
